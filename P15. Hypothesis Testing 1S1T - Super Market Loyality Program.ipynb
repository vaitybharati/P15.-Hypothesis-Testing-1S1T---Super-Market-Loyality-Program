# %% [markdown]
# # Hypothesis Testing 1S1T - Super Market Loyality Program

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
from scipy import stats
from scipy.stats import norm

# %% [raw]
# Population Parameters: Mean=120
# Sample Parameters: n=80, Mean=130, SD=40, df=80-1=79
#
# 1-sample 1-tail ttest
#
# Assume Null Hypothesis Ho as Avg spending <= $120
# Thus Alternate Hypothesis Ha as Avg spending > $120

# %%
# Find t_value = (s_mean - p_mean)/(s_SD/sqrt(n))
t_value=(130-120)/(40/np.sqrt(80))
t_value
# Out:
# 2.23606797749979

# %%
# Find Probability P(X<t) (One-Tail Test value) so as to compare with Type-1 error α = 0.05
p_value=1-stats.t.cdf(t_value,df=79)
p_value
# Out:
# 0.014084316277010789

# %% [raw]
# As (p-value = 0.014) < (α = 0.05); Reject Null Hypothesis
# Thus Avg spending > $120; we can go ahead and launch Loyality program.
